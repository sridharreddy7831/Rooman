# %% [markdown]
# # Sridhar Attendance

# %%
import pandas as pd

# Your input data
data = [
    ['12-03-2025 11:58:28', '12-03-2025 14:45:24'],
    ['13-03-2025 09:48:57', '13-03-2025 14:54:36'],
    ['14-03-2025 09:27:23', '14-03-2025 14:46:20'],
    ['15-03-2025 09:29:39', '15-03-2025 15:05:19'],
    ['17-03-2025 09:19:49', '17-03-2025 14:55:53'],
    ['18-03-2025 09:23:17', '18-03-2025 15:00:35'],
    ['19-03-2025 09:21:05', '19-03-2025 16:53:52'],
    ['20-03-2025 09:21:50', '20-03-2025 16:39:08'],
    ['21-03-2025 09:28:17', '21-03-2025 14:23:42'],
    ['22-03-2025 09:26:30', '22-03-2025 13:18:08'],
    ['24-03-2025 09:26:01', '24-03-2025 18:21:24'],
    ['25-03-2025 09:25:56', '25-03-2025 17:15:31'],
    ['26-03-2025 09:26:41', '26-03-2025 16:15:15'],
    ['27-03-2025 09:21:04', '27-03-2025 18:25:51'],
    ['28-03-2025 09:27:17', '28-03-2025 17:36:34'],
    ['29-03-2025 09:30:43', '29-03-2025 17:57:21'],
    ['31-03-2025 07:55:34', '31-03-2025 17:48:52'],
    ['01-04-2025 09:37:38', '01-04-2025 16:58:38'],
    ['02-04-2025 07:56:14', '02-04-2025 18:19:19'],
    ['03-04-2025 08:04:59', '03-04-2025 18:24:37'],
    ['04-04-2025 08:00:34', '04-04-2025 18:18:44'],
    ['05-04-2025 08:06:42', '05-04-2025 18:28:58'],
    ['07-04-2025 09:36:37', '07-04-2025 18:17:01'],
    ['09-04-2025 07:56:39', '09-04-2025 18:41:36'],
    ['10-04-2025 08:02:29', '10-04-2025 17:54:19'],
    ['11-04-2025 08:03:33', '11-04-2025 17:58:14'],
    ['12-04-2025 08:00:36', '12-04-2025 17:55:25']
]

# Create DataFrame
df = pd.DataFrame(data, columns=["In Time", "Out Time"])

# Convert columns to datetime
df["In Time"] = pd.to_datetime(df["In Time"], format="%d-%m-%Y %H:%M:%S")
df["Out Time"] = pd.to_datetime(df["Out Time"], format="%d-%m-%Y %H:%M:%S")

# Calculate stay duration in hours (rounded to 2 decimals)
df["Stay Duration (hrs)"] = (df["Out Time"] - df["In Time"]).dt.total_seconds() / 3600
df["Stay Duration (hrs)"] = df["Stay Duration (hrs)"].round(2)

# Print the results
# print(df[["In Time", "Out Time", "Stay Duration (hrs)"]])

# Print total hours
total_hours = df["Stay Duration (hrs)"].sum()
print(f"\n🕒 Nalipi's Total Stay Duration: {round(total_hours, 2)} hours")
# Out:
# 🕒 Nalipi's Total Stay Duration: 210.57 hours

# %% [markdown]
# # Pravalli Attendance

# %%
import pandas as pd

# Sample data (replace with actual full data if reading from CSV)
data = {
    'In Time': [
        "12-03-2025 12:06:18", "13-03-2025 09:47:42", "14-03-2025 09:32:19", "15-03-2025 09:29:33",
        "17-03-2025 09:19:28", "18-03-2025 09:23:33", "19-03-2025 09:20:49", "20-03-2025 09:20:47",
        "21-03-2025 09:26:14", "22-03-2025 09:25:47", "24-03-2025 09:25:27", "25-03-2025 09:25:30",
        "26-03-2025 09:26:28", "27-03-2025 09:20:48", "28-03-2025 09:27:23", "29-03-2025 09:31:06",
        "31-03-2025 09:22:42", "01-04-2025 09:34:57", "02-04-2025 07:56:01", "03-04-2025 08:04:43",
        "04-04-2025 08:00:14", "05-04-2025 08:06:21", "07-04-2025 10:25:15", "08-04-2025 07:05:17",
        "09-04-2025 07:56:20", "10-04-2025 07:50:13", "11-04-2025 08:03:13", "12-04-2025 07:59:50"
    ],
    'Out Time': [
        "12-03-2025 14:46:45", "13-03-2025 14:55:38", "14-03-2025 14:45:50", "15-03-2025 13:04:54",
        "17-03-2025 14:54:11", "18-03-2025 15:00:06", "19-03-2025 16:52:39", "20-03-2025 16:38:33",
        "21-03-2025 14:23:07", "22-03-2025 13:17:44", "24-03-2025 18:21:01", "25-03-2025 17:15:53",
        "26-03-2025 16:14:45", "27-03-2025 18:21:51", "28-03-2025 17:37:00", "29-03-2025 17:57:54",
        "31-03-2025 17:49:50", "01-04-2025 18:21:25", "02-04-2025 18:19:25", "03-04-2025 18:24:59",
        "04-04-2025 18:19:12", "05-04-2025 18:30:01", "07-04-2025 18:17:06", "08-04-2025 13:23:03",
        "09-04-2025 18:41:11", "10-04-2025 17:57:34", "11-04-2025 17:54:37", "12-04-2025 17:55:57"
    ]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Convert to datetime
df['In Time'] = pd.to_datetime(df['In Time'], format="%d-%m-%Y %H:%M:%S")
df['Out Time'] = pd.to_datetime(df['Out Time'], format="%d-%m-%Y %H:%M:%S")

# Calculate Stay Duration
df['Stay Duration'] = df['Out Time'] - df['In Time']

# Convert Stay Duration to hours
df['Stay in Hours'] = df['Stay Duration'].dt.total_seconds() / 3600

# Display table
# print(df[['In Time', 'Out Time', 'Stay Duration', 'Stay in Hours']])

# Calculate and print total hours
total_hours = df['Stay in Hours'].sum()
print(f"\n✅ Pravalli's Total Stay Duration: {total_hours:.2f} hours")
# Out:
# ✅ Pravalli's Total Stay Duration: 214.13 hours

# %% [markdown]
# # Meghana Attendance

# %%
import pandas as pd

# Extracted data from your images
data = [
    ['12-03-2025 12:14:29', '12-03-2025 14:44:50'],
    ['13-03-2025 09:47:00', '13-03-2025 14:54:25'],
    ['14-03-2025 09:31:25', '14-03-2025 14:46:27'],
    ['15-03-2025 09:35:40', '15-03-2025 13:05:39'],
    ['17-03-2025 09:34:40', '17-03-2025 14:55:18'],
    ['18-03-2025 09:35:31', '18-03-2025 15:00:28'],
    ['19-03-2025 09:33:58', '19-03-2025 16:54:15'],
    ['20-03-2025 09:36:56', '20-03-2025 16:39:39'],
    ['21-03-2025 09:27:00', '21-03-2025 14:22:48'],
    ['22-03-2025 09:25:21', '22-03-2025 13:18:40'],
    ['24-03-2025 11:34:07', '24-03-2025 18:07:21'],
    ['25-03-2025 09:42:20', '25-03-2025 17:16:14'],
    ['26-03-2025 09:26:50', '26-03-2025 16:15:30'],
    ['27-03-2025 09:38:58', '27-03-2025 18:25:02'],
    ['03-04-2025 09:33:57', '03-04-2025 18:25:16'],
    ['04-04-2025 09:42:11', '04-04-2025 18:07:17'],
    ['05-04-2025 09:43:59', '05-04-2025 18:40:53'],
    ['07-04-2025 09:38:59', '07-04-2025 18:27:39'],
    ['08-04-2025 09:59:38', '08-04-2025 14:43:55'],
    ['09-04-2025 09:48:38', '09-04-2025 18:41:55'],
    ['10-04-2025 09:54:54', '10-04-2025 17:58:30'],
    ['11-04-2025 09:45:17', '11-04-2025 18:05:40'],
    ['12-04-2025 10:00:44', '12-04-2025 18:06:36']
]

# Create DataFrame
df = pd.DataFrame(data, columns=["In Time", "Out Time"])

# Convert columns to datetime
df["In Time"] = pd.to_datetime(df["In Time"], format="%d-%m-%Y %H:%M:%S")
df["Out Time"] = pd.to_datetime(df["Out Time"], format="%d-%m-%Y %H:%M:%S")

# Calculate stay duration in hours (rounded to 2 decimals)
df["Stay Duration (hrs)"] = (df["Out Time"] - df["In Time"]).dt.total_seconds() / 3600
df["Stay Duration (hrs)"] = df["Stay Duration (hrs)"].round(2)

# Print the results
# print(df[["In Time", "Out Time", "Stay Duration (hrs)"]])

# Print total hours
total_hours = df["Stay Duration (hrs)"].sum()
print(f"\n🕒 Total Stay Duration: {round(total_hours, 2)} hours")
# Out:
# 🕒 Total Stay Duration: 153.21 hours

# %% [markdown]
# # Hemanth Attendance

# %%
import pandas as pd

# Data extracted from the screenshots
data = [
    ['12-03-2025 12:00:51', '12-03-2025 14:46:09'],
    ['13-03-2025 09:48:24', '13-03-2025 14:54:34'],
    ['14-03-2025 09:30:48', '14-03-2025 14:46:00'],
    ['18-03-2025 09:25:38', '18-03-2025 14:59:31'],
    ['19-03-2025 09:21:26', '19-03-2025 16:53:23'],
    ['20-03-2025 09:22:34', '20-03-2025 17:14:21'],
    ['21-03-2025 09:26:36', '21-03-2025 14:24:05'],
    ['22-03-2025 09:26:09', '22-03-2025 13:17:36'],
    ['24-03-2025 09:33:26', '24-03-2025 18:06:58'],
    ['25-03-2025 10:11:08', '25-03-2025 18:10:08'],
    ['27-03-2025 09:38:36', '27-03-2025 18:25:22'],
    ['03-04-2025 09:33:38', '03-04-2025 18:40:58'],
    ['04-04-2025 08:03:15', '04-04-2025 18:07:00'],
    ['05-04-2025 08:05:24', '05-04-2025 18:40:34'],
    ['07-04-2025 09:39:52', '07-04-2025 18:27:31'],
    ['08-04-2025 07:54:33', '08-04-2025 12:03:03'],
    ['09-04-2025 07:58:03', '09-04-2025 18:41:53'],
    ['10-04-2025 07:51:17', '10-04-2025 18:30:02'],
    ['11-04-2025 08:10:51', '11-04-2025 18:08:39'],
    ['12-04-2025 07:34:06', '12-04-2025 18:06:18']
]

# Create DataFrame
df = pd.DataFrame(data, columns=["In Time", "Out Time"])

# Convert to datetime
df["In Time"] = pd.to_datetime(df["In Time"], format="%d-%m-%Y %H:%M:%S")
df["Out Time"] = pd.to_datetime(df["Out Time"], format="%d-%m-%Y %H:%M:%S")

# Calculate stay duration
df["Stay Duration (hrs)"] = (df["Out Time"] - df["In Time"]).dt.total_seconds() / 3600
df["Stay Duration (hrs)"] = df["Stay Duration (hrs)"].round(2)

# Total stay
total_hours = df["Stay Duration (hrs)"].sum()
# print(df[["In Time", "Out Time", "Stay Duration (hrs)"]])
print(f"\n🕒 Hemanth's Total Stay Duration: {round(total_hours, 2)} hours")
# Out:
# 🕒 Hemanth's Total Stay Duration: 152.78 hours
